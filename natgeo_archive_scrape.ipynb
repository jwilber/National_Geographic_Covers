# %%
import time

import pandas as pd

from bs4 import BeautifulSoup
from selenium import webdriver

# %%
base_url = "https://archive.nationalgeographic.com/rvimageserver/National%20Geographic%20Society/National%20Geographic/NGM_{year}_{month}/page0000001.jpg?type=1&amp;width=824&amp;quality=70&amp;v=v1"

# %%
new_url = "https://archive.nationalgeographic.com/dynamic/National%20Geographic%20Society/National%20Geographic/Home.aspx"

driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)
time.sleep(3)
content = driver.page_source.encode('utf-8').strip()
soup = BeautifulSoup(content,"html.parser")

# do stuff

# driver.quit()

# %%
soup.find_all('img')[0]['src']
# Out:
# 'https://archive.nationalgeographic.com/rvimageserver/National%20Geographic%20Society/National%20Geographic/NGM_1975_02/page0000001.jpg?type=3&amp;width=824&amp;quality=70&amp;v=v1'

# %%
archive_df = []
for year in range(1960, 2019):
    for month in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']:
        issue = {
            'issue_year': str(year),
            'issue_month': month,
            'cover_image_url': base_url.format(year=year, month=month)
            }
        archive_df.append(issue)
t = pd.DataFrame(archive_df)

# %%
t.to_csv('national_geographic_covers.csv')

# %%
t
# Out:
#                                                img_url month  year
# 0    https://archive.nationalgeographic.com/rvimage...    01  1960
# 1    https://archive.nationalgeographic.com/rvimage...    02  1960
# 2    https://archive.nationalgeographic.com/rvimage...    03  1960
# 3    https://archive.nationalgeographic.com/rvimage...    04  1960
# 4    https://archive.nationalgeographic.com/rvimage...    05  1960
# 5    https://archive.nationalgeographic.com/rvimage...    06  1960
# 6    https://archive.nationalgeographic.com/rvimage...    07  1960
# 7    https://archive.nationalgeographic.com/rvimage...    08  1960
# 8    https://archive.nationalgeographic.com/rvimage...    09  1960
# 9    https://archive.nationalgeographic.com/rvimage...    10  1960
# 10   https://archive.nationalgeographic.com/rvimage...    11  1960
# 11   https://archive.nationalgeographic.com/rvimage...    12  1960
# 12   https://archive.nationalgeographic.com/rvimage...    01  1961
# ...
